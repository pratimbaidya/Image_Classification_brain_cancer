# %% [markdown]
# ****This is a image classification task where I am classifying between 3 types of brain cancer, Menin, Glioma and Tumor.****

# %% [markdown]
# This below code directly downloads the data so the reader does not have to go through the hasstle of downloading the data and setting it up for the code.

# %%
import os

# Install gdown if you haven't already
# !pip install gdown

# Replace 'YOUR_FILE_ID_FOR_THE_ZIP' with the actual ID you copied
file_id = '10w2Lkl_se2ApcFq3m-yg_c1S9pWHutmy'
output_filename = 'brain_cancer_image_dataset.zip' # Give it a meaningful name

# !gdown {file_id} -O {output_filename}

if not os.path.exists("/content/Data_folder"):
  os.makedirs("/content/Data_folder")

# Unzip the file
# !unzip {output_filename} -d /content/Data_folder # Choose your desired destination folder
# -d flag specifies the directory to extract to. Create it if needed: !mkdir /content/Data_folder
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1060.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1061.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1062.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1063.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1064.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1065.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1066.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1067.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1068.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1069.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1070.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1071.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1072.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1073.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1074.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1075.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1076.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1077.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1078.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1079.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1080.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1081.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1082.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1083.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1084.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1085.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1086.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1087.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1088.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1089.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1090.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1091.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1092.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1093.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1094.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1095.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1096.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1097.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1098.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1099.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1100.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1101.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1102.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1103.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1104.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1105.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1106.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1107.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1108.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1109.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1110.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1111.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1112.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1113.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1114.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1115.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1116.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1117.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1118.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1119.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1120.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1121.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1122.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1123.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1124.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1125.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1126.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1127.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1128.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1129.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1130.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1131.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1132.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1133.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1134.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1135.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1136.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1137.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1138.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1139.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1140.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1141.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1142.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1143.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1144.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1145.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1146.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1147.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1148.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1149.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1150.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1151.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1152.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1153.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1154.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1155.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1156.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1157.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1158.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1159.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1160.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1161.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1162.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1163.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1164.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1165.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1166.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1167.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1168.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1169.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1170.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1171.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1172.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1173.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1174.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1175.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1176.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1177.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1178.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1179.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1180.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1181.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1182.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1183.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1184.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1185.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1186.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1187.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1188.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1189.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1190.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1191.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1192.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1193.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1194.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1195.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1196.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1197.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1198.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1199.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1200.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1201.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1202.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1203.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1204.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1205.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1206.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1207.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1208.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1209.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1210.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1211.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1212.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1213.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1214.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1215.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1216.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1217.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1218.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1219.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1220.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1221.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1222.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1223.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1224.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1225.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1226.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1227.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1228.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1229.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1230.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1231.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1232.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1233.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1234.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1235.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1236.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1237.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1238.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1239.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1240.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1241.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1242.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1243.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1244.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1245.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1246.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1247.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1248.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1249.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1250.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1251.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1252.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1253.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1254.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1255.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1256.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1257.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1258.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1259.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1260.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1261.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1262.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1263.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1264.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1265.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1266.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1267.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1268.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1269.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1270.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1271.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1272.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1273.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1274.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1275.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1276.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1277.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1278.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1279.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1280.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1281.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1282.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1283.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1284.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1285.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1286.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1287.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1288.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1289.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1290.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1291.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1292.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1293.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1294.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1295.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1296.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1297.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1298.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1299.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1300.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1301.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1302.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1303.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1304.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1305.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1306.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1307.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1308.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1309.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1310.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1311.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1312.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1313.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1314.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1315.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1316.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1317.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1318.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1319.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1320.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1321.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1322.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1323.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1324.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1325.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1326.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1327.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1328.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1329.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1330.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1331.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1332.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1333.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1334.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1335.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1336.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1337.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1338.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1339.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1340.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1341.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1342.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1343.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1344.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1345.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1346.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1347.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1348.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1349.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1350.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1351.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1352.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1353.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1354.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1355.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1356.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1357.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1358.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1359.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1360.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1361.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1362.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1363.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1364.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1365.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1366.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1367.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1368.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1369.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1370.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1371.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1372.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1373.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1374.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1375.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1376.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1377.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1378.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1379.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1380.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1381.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1382.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1383.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1384.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1385.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1386.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1387.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1388.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1389.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1390.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1391.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1392.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1393.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1394.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1395.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1396.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1397.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1398.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1399.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1400.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1401.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1402.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1403.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1404.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1405.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1406.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1407.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1408.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1409.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1410.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1411.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1412.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1413.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1414.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1415.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1416.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1417.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1418.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1419.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1420.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1421.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1422.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1423.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1424.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1425.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1426.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1427.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1428.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1429.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1430.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1431.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1432.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1433.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1434.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1435.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1436.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1437.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1438.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1439.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1440.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1441.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1442.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1443.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1444.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1445.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1446.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1447.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1448.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1449.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1450.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1451.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1452.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1453.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1454.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1455.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1456.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1457.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1458.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1459.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1460.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1461.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1462.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1463.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1464.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1465.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1466.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1467.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1468.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1469.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1470.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1471.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1472.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1473.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1474.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1475.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1476.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1477.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1478.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1479.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1480.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1481.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1482.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1483.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1484.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1485.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1486.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1487.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1488.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1489.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1490.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1491.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1492.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1493.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1494.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1495.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1496.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1497.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1498.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1499.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1500.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1501.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1502.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1503.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1504.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1505.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1506.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1507.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1508.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1509.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1510.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1511.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1512.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1513.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1514.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1515.jpg
# ...
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1851.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1852.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1853.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1854.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1855.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1856.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1857.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1858.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1859.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1860.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1861.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1862.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1863.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1864.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1865.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1866.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1867.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1868.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1869.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1870.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1871.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1872.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1873.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1874.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1875.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1876.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1877.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1878.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1879.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1880.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1881.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1882.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1883.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1884.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1885.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1886.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1887.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1888.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1889.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1890.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1891.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1892.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1893.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1894.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1895.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1896.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1897.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1898.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1899.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1900.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1901.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1902.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1903.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1904.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1905.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1906.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1907.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1908.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1909.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1910.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1911.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1912.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1913.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1914.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1915.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1916.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1917.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1918.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1919.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1920.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1921.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1922.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1923.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1924.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1925.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1926.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1927.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1928.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1929.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1930.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1931.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1932.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1933.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1934.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1935.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1936.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1937.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1938.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1939.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1940.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1941.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1942.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1943.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1944.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1945.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1946.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1947.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1948.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1949.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1950.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1951.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1952.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1953.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1954.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1955.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1956.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1957.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1958.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1959.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1960.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1961.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1962.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1963.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1964.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1965.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1966.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1967.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1968.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1969.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1970.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1971.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1972.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1973.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1974.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1975.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1976.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1977.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1978.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1979.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1980.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1981.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1982.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1983.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1984.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1985.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1986.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1987.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1988.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1989.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1990.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1991.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1992.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1993.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1994.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1995.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1996.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1997.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1998.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1999.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_2000.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_2001.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_2002.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_2003.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_2004.jpg
#   inflating: /content/Data_folder/Brain Cancer Dataset/dataset.csv

# %% [markdown]
# Installing the which libraries which is not preinstalled in colab

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %% [markdown]
# Let's Import the required libraries.

# %%
import os
import sys
from collections import Counter

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import PIL
from PIL import Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchinfo
from PIL import Image
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader, ConcatDataset, Subset, random_split
from torchinfo import summary
from torchvision import datasets, transforms, models
from tqdm.notebook import tqdm

# %% [markdown]
# Setting up our device so that we can use the GPU

# %%
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

print(f"Using {device} device.")
# Out:
# Using cuda device.

# %% [markdown]
# Setting up the data directory and get the labels for our data.

# %%
data_dir = "/content/Data_folder/Brain Cancer Dataset/Brain_Cancer"
labels = os.listdir(data_dir)
labels
# Out:
# ['brain_menin', 'brain_glioma', 'brain_tumor']

# %% [markdown]
# As we can see there are three types of images. These are the classes for this project.

# %% [markdown]
# Now lets create paths for each of the classe's folders.

# %%
brain_menin_path = os.path.join(data_dir, 'brain_menin')
brain_glioma_path = os.path.join(data_dir, 'brain_glioma')
brain_tumor_path = os.path.join(data_dir, 'brain_tumor')

# %% [markdown]
# Finding out how many images we have for each class in the dataset.

# %%
brain_menin_images = os.listdir(brain_menin_path)
brain_glioma_images = os.listdir(brain_glioma_path)
brain_tumor_images = os.listdir(brain_tumor_path)

# %%
print(f"Number of Menin image: {len(brain_menin_images)}")
print(f"Number of Glioma image: {len(brain_glioma_images)}")
print(f"Number of Tumor image: {len(brain_tumor_images)}")
# Out:
# Number of Menin image: 2004
# Number of Glioma image: 2004
# Number of Tumor image: 2048

# %% [markdown]
# As we can see the dataset is quite balanced between the classes.

# %% [markdown]
# Now let's go a little deeper and check out how the images look like. We will check out one image for each class. Lets create paths for the first image for each class.

# %%
menin_image_name = brain_menin_images[0]
print(menin_image_name)

menin_image_path = os.path.join(brain_menin_path, menin_image_name)
print(menin_image_path)


glioma_image_name = brain_glioma_images[0]
print(glioma_image_name)

glioma_image_path = os.path.join(brain_glioma_path, glioma_image_name)
print(glioma_image_path)


tumor_image_name = brain_tumor_images[0]
print(tumor_image_name)

tumor_image_path = os.path.join(brain_tumor_path, tumor_image_name)
print(tumor_image_path)
# Out:
# brain_menin_0151.jpg
# /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_menin/brain_menin_0151.jpg
# brain_glioma_1211.jpg
# /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_1211.jpg
# brain_tumor_1163.jpg
# /content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_tumor/brain_tumor_1163.jpg

# %% [markdown]
# We will use Python Imaging Library to load the images.

# %%
menin_image_pil = Image.open(menin_image_path)
print("Blank image: ", menin_image_pil.mode, menin_image_pil.size)

glioma_image_pil = Image.open(glioma_image_path)
print("Hog image: ", glioma_image_pil.mode, glioma_image_pil.size)

tumor_image_pil = Image.open(tumor_image_path)
print("Blank image: ", tumor_image_pil.mode, tumor_image_pil.size)
# Out:
# Blank image:  RGB (512, 512)
# Hog image:  RGB (512, 512)
# Blank image:  RGB (512, 512)

# %% [markdown]
# As we can see the images are all RGB images of size 512*512 piexls.

# %% [markdown]
# Lets view all three images from each classes.

# %%
menin_image_pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
glioma_image_pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
tumor_image_pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %% [markdown]
# Lets create a callable class which will convert all the non-RGB images into RGB images. If there is some grayscale image in our data, the function will turn that into a 3 channel grayscale image to match the dimention of the RGB image. Basically same image coppied into three channel.

# %%
class ConvertToRGB:
    def __call__(self, img):
        return img.convert("RGB")

# %% [markdown]
# We will use the ConvertToRGB function along with other transformations. We will change the image into an RGB image (if not already). Then resize it as 224*224 image. Then turn it into a PyTorch tensor. transforms.ToTensor() also scales all the values in the tensor between [0,1].

# %% [markdown]
# This is our primary level transformation. We will come to this latter on to apply Normalization.

# %%
# Transformations to apply to the images
transform = transforms.Compose(
    [
        ConvertToRGB(),
        transforms.Resize((256, 256)),
        transforms.CenterCrop((224, 224)),
        transforms.ToTensor()
    ]
)

print(type(transform))
print(transform)
# Out:
# <class 'torchvision.transforms.transforms.Compose'>
# Compose(
#     <__main__.ConvertToRGB object at 0x7f138cc161d0>
#     Resize(size=(256, 256), interpolation=bilinear, max_size=None, antialias=True)
#     CenterCrop(size=(224, 224))
#     ToTensor()
# )

# %% [markdown]
# Torchvision datasets.ImageFolder class makes it very easy to work with data if arranged in folders. Lets crteate a dataset object using this.

# %%
# Load the dataset using `ImageFolder`
dataset = datasets.ImageFolder(root=data_dir, transform=transform)
print(dataset)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 6056
#     Root location: /content/Data_folder/Brain Cancer Dataset/Brain_Cancer
#     StandardTransform
# Transform: Compose(
#                <__main__.ConvertToRGB object at 0x7f138cc161d0>
#                Resize(size=(256, 256), interpolation=bilinear, max_size=None, antialias=True)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#            )

# %% [markdown]
# We can check the classes.

# %%
dataset.classes
# Out:
# ['brain_glioma', 'brain_menin', 'brain_tumor']

# %% [markdown]
# dataset.samples givs us a list of tuple which has file path for the image and label for the image. lets check out all the distinct class labels

# %%
im = dataset.samples
print(im[0])

distinct_classes = {x[1] for x in im}
print(distinct_classes)
# Out:
# ('/content/Data_folder/Brain Cancer Dataset/Brain_Cancer/brain_glioma/brain_glioma_0001.jpg', 0)
# {0, 1, 2}

# %% [markdown]
# Lets create a class to index mapping as it will be required for class counting for our subsets

# %%
class_to_idx_mapping = dataset.class_to_idx
class_to_idx_mapping
# Out:
# {'brain_glioma': 0, 'brain_menin': 1, 'brain_tumor': 2}

# %% [markdown]
# We want to calculate mean and std for the images across 3 channels so that we can use it to Normalize the images. To do that we will create a data loader object of our dataset and then use a custom function to calculate mean and std.

# %% [markdown]
# Lets create the dataloader object

# %%
dataloader = DataLoader(dataset, 32)

# %% [markdown]
# Let's create a function which will calculate the mean and std of the images. This function takes a dataloader object and returns mean and std along 3 channels of the images.

# %%
def get_mean_std(loader):
    """Computes the mean and standard deviation of image data.

    Input: a `DataLoader` producing tensors of shape [batch_size, channels, pixels_x, pixels_y]
    Output: the mean of each channel as a tensor, the standard deviation of each channel as a tensor
            formatted as a tuple (means[channels], std[channels])"""

    channels_sum, channels_squared_sum, num_batches = 0, 0, 0
    for data, _ in tqdm(loader, desc="Computing mean and std", leave=False):
        channels_sum += torch.mean(data, dim=[0, 2, 3])
        channels_squared_sum += torch.mean(data**2, dim=[0, 2, 3])
        num_batches += 1
    mean = channels_sum / num_batches
    std = (channels_squared_sum / num_batches - mean**2) ** 0.5

    return mean, std

# %% [markdown]
# Now lets compute the mean and std of the images along 3 channels for all of our dataset.

# %%
mean, std = get_mean_std(dataloader)
print(f"Mean across 3 channels R G B: {mean}")
print(f"Standard Deviation across 3 channels R G B: {std}")
# Out:
# Computing mean and std:   0%|          | 0/190 [00:00<?, ?it/s]
# Mean across 3 channels R G B: tensor([0.1898, 0.1898, 0.1898])
# Standard Deviation across 3 channels R G B: tensor([0.1732, 0.1732, 0.1732])

# %% [markdown]
# Now We will use **data augmentation**. To do that lets create a new function which will take our whole dataset and retun train, validation and test data loader objects. We will specify also use the split ratios in here.

# %% [markdown]
# Lets create a function using which we can apply transformations directly to the substes of the data.

# %%
class TransformedSubsetDataset(torch.utils.data.Dataset):
    def __init__(self, subset: Subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __len__(self):
        return len(self.subset)

    def __getitem__(self, idx):
        img, label = self.subset.dataset[self.subset.indices[idx]]
        if self.transform:
            img = self.transform(img)
        return img, label

# %% [markdown]
# Lets create transformations which will be applied to our datasets. One transformation will be created for the training set and other transformation will be created for the augmented training set.

# %%
# Augmented transformation1
transform_aug1 = transforms.Compose([
    ConvertToRGB(),
    transforms.Resize((256, 256)),
    transforms.RandomCrop((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])

# Augmented transformation2
transform_aug2 = transforms.Compose([
    ConvertToRGB(),
    transforms.Resize((256, 256)),
    transforms.RandomCrop((224, 224)),
    transforms.RandomRotation(degrees=30, interpolation=Image.BILINEAR),
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])

augmented_transformations = [transform_aug1, transform_aug2]

# %% [markdown]
# Now lets create our augmentation function

# %%
# Augmentation Function
def subset_dataset(root_dir, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15, augmented_transforms=None, random_seed=42):
    # Ensure ratios sum to 1 (approximately)
    assert abs(train_ratio + val_ratio + test_ratio - 1.0) < 1e-6

    # Define transforms
    # Transform for validation and test sets (and base training set if not augmented)
    transform_eval = transforms.Compose([
        ConvertToRGB(),
        transforms.Resize((256, 256)),
        transforms.CenterCrop((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])

    full_dataset = datasets.ImageFolder(root=root_dir, transform=None)

    # Get indices and labels for stratified splitting
    all_indices = list(range(len(full_dataset)))
    all_labels = np.array([s[1] for s in full_dataset.samples])

    # First, split into train_val_indices and test_indices
    train_val_indices, test_indices, _, _ = train_test_split(
        all_indices, all_labels,
        test_size=test_ratio,
        stratify=all_labels,
        random_state=random_seed
    )

    # Then, split train_val_indices into train_indices and val_indices
    relative_val_ratio = val_ratio / (train_ratio + val_ratio)
    train_indices, val_indices, _, _ = train_test_split(
        train_val_indices, all_labels[np.array(train_val_indices)],
        test_size=relative_val_ratio,
        stratify=all_labels[np.array(train_val_indices)],
        random_state=random_seed
    )

    # Then, create the subsets of the full dataset
    base_train_subset = Subset(full_dataset, train_indices)
    base_val_subset = Subset(full_dataset, val_indices)
    base_test_subset = Subset(full_dataset, test_indices)

    # 4. Wrap Subsets with TransformedSubsetDataset to apply specific transforms
    val_set = TransformedSubsetDataset(base_val_subset, transform=transform_eval)
    test_set = TransformedSubsetDataset(base_test_subset, transform=transform_eval)

    if augmented_transforms:
        train_set_original = TransformedSubsetDataset(base_train_subset, transform=transform_eval)
        augmented_train_set = list()
        augmented_train_set.append(train_set_original)
        for transform in augmented_transforms:
          aug_train_set = TransformedSubsetDataset(base_train_subset, transform=transform)
          augmented_train_set.append(aug_train_set)

        # Concatenate all training sets
        train_set = ConcatDataset(augmented_train_set)
    else:
        # If no augmentation, just use the standard transform for the training set
        train_set = TransformedSubsetDataset(base_train_subset, transform=transform_eval)

    return train_set, val_set, test_set

# %% [markdown]
# First we will use Normal splits to train our model. Then we will use Augmened training dataset to train our model and see if we get any improvements.

# %% [markdown]
# Lets get our Normal train, val and test sets

# %%
train_set, val_set, test_set = subset_dataset(data_dir, 0.7, 0.2, 0.1)

# %%
print(f"Length of training set: {len(train_set)}")
print(f"Length of validation set: {len(val_set)}")
print(f"Length of test set: {len(test_set)}")
# Out:
# Length of training set: 4238
# Length of validation set: 1212
# Length of test set: 606

# %% [markdown]
# lets create a function which will count for the classses in each of the datasets. this function returns a pandas series where the indices are the classes and values are the respective count for each class.

# %%
def class_counts(dataset, class_to_index):
    if isinstance(dataset, ConcatDataset):
        all_labels = []
        for sub_dataset in dataset.datasets:
            for idx_in_sub in range(len(sub_dataset)):
                global_idx = sub_dataset.subset.indices[idx_in_sub]
                all_labels.append(sub_dataset.subset.dataset.samples[global_idx][1])
    else:
        all_labels = [x[1] for x in tqdm(dataset, desc="Counting classes")]

    c = Counter(all_labels)
    return pd.Series({cat: c[idx] for cat, idx in class_to_index.items()})

# %%
train_class_count = class_counts(train_set, class_to_idx_mapping)
train_class_count
# Out:
# Counting classes:   0%|          | 0/4238 [00:00<?, ?it/s]
# brain_glioma    1402
# brain_menin     1403
# brain_tumor     1433
# dtype: int64

# %% [markdown]
# lets plot the class count for our training set.

# %%
train_class_count.sort_values().plot(kind="bar");

# %% [markdown]
# doing the same for the val_dataset

# %%
val_class_count = class_counts(val_set, class_to_idx_mapping)
val_class_count
# Out:
# Counting classes:   0%|          | 0/1212 [00:00<?, ?it/s]
# brain_glioma    401
# brain_menin     401
# brain_tumor     410
# dtype: int64

# %%
val_class_count.sort_values().plot(kind="bar");

# %% [markdown]
# same for test_dataset

# %%
test_class_count = class_counts(test_set, class_to_idx_mapping)
test_class_count
# Out:
# Counting classes:   0%|          | 0/606 [00:00<?, ?it/s]
# brain_glioma    201
# brain_menin     200
# brain_tumor     205
# dtype: int64

# %%
test_class_count.sort_values().plot(kind="bar");

# %% [markdown]
# As we can see for the three datasets, we have balanced datasets for all the classes.

# %% [markdown]
# Now let's crteate our new DataLoader for each of the normalized datasets. We will use batch size of 32. We will shuffle the training set but not the val or test set.

# %%
g = torch.Generator().manual_seed(42)

batch_size = 32

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, generator=g, pin_memory=True)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False, generator=g, pin_memory=True)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False, generator=g, pin_memory=True)

# %% [markdown]
# Dataloader creates a iterator. So we can access its items using iter and next function

# %%
batch, label = next(iter(train_loader))

# %% [markdown]
# Lets inspect this one batch of data and the corresponding labels

# %%
print(f'Shape of the batch: {batch.shape}')
print(f'Shape of the label: {label.shape}')
# Out:
# Shape of the batch: torch.Size([32, 3, 224, 224])
# Shape of the label: torch.Size([32])

# %%
label
# Out:
# tensor([0, 2, 1, 1, 2, 0, 0, 0, 2, 0, 0, 0, 0, 0, 1, 2, 1, 0, 1, 2, 2, 2, 2, 1,
#         0, 1, 1, 2, 0, 2, 1, 2])

# %% [markdown]
# As we can see each of the batch has 32 images of size 3x224x224. and the label contains the corresponding labels for those 32 images.

# %% [markdown]
# In this project we will a pre-trained model to do the image classification. We will be using the resnet50 model. Lets brinng our model from torchvision library.

# %%
model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 201MB/s]

# %% [markdown]
# Lets check our model summary using one batch of the training data

# %%
summary(model, input_size=batch.shape)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNet                                   [32, 1000]                --
# ├─Conv2d: 1-1                            [32, 64, 112, 112]        9,408
# ├─BatchNorm2d: 1-2                       [32, 64, 112, 112]        128
# ├─ReLU: 1-3                              [32, 64, 112, 112]        --
# ├─MaxPool2d: 1-4                         [32, 64, 56, 56]          --
# ├─Sequential: 1-5                        [32, 256, 56, 56]         --
# │    └─Bottleneck: 2-1                   [32, 256, 56, 56]         --
# │    │    └─Conv2d: 3-1                  [32, 64, 56, 56]          4,096
# │    │    └─BatchNorm2d: 3-2             [32, 64, 56, 56]          128
# │    │    └─ReLU: 3-3                    [32, 64, 56, 56]          --
# │    │    └─Conv2d: 3-4                  [32, 64, 56, 56]          36,864
# │    │    └─BatchNorm2d: 3-5             [32, 64, 56, 56]          128
# │    │    └─ReLU: 3-6                    [32, 64, 56, 56]          --
# │    │    └─Conv2d: 3-7                  [32, 256, 56, 56]         16,384
# │    │    └─BatchNorm2d: 3-8             [32, 256, 56, 56]         512
# │    │    └─Sequential: 3-9              [32, 256, 56, 56]         16,896
# │    │    └─ReLU: 3-10                   [32, 256, 56, 56]         --
# │    └─Bottleneck: 2-2                   [32, 256, 56, 56]         --
# │    │    └─Conv2d: 3-11                 [32, 64, 56, 56]          16,384
# │    │    └─BatchNorm2d: 3-12            [32, 64, 56, 56]          128
# │    │    └─ReLU: 3-13                   [32, 64, 56, 56]          --
# │    │    └─Conv2d: 3-14                 [32, 64, 56, 56]          36,864
# │    │    └─BatchNorm2d: 3-15            [32, 64, 56, 56]          128
# │    │    └─ReLU: 3-16                   [32, 64, 56, 56]          --
# │    │    └─Conv2d: 3-17                 [32, 256, 56, 56]         16,384
# │    │    └─BatchNorm2d: 3-18            [32, 256, 56, 56]         512
# │    │    └─ReLU: 3-19                   [32, 256, 56, 56]         --
# │    └─Bottleneck: 2-3                   [32, 256, 56, 56]         --
# │    │    └─Conv2d: 3-20                 [32, 64, 56, 56]          16,384
# │    │    └─BatchNorm2d: 3-21            [32, 64, 56, 56]          128
# │    │    └─ReLU: 3-22                   [32, 64, 56, 56]          --
# │    │    └─Conv2d: 3-23                 [32, 64, 56, 56]          36,864
# │    │    └─BatchNorm2d: 3-24            [32, 64, 56, 56]          128
# │    │    └─ReLU: 3-25                   [32, 64, 56, 56]          --
# │    │    └─Conv2d: 3-26                 [32, 256, 56, 56]         16,384
# │    │    └─BatchNorm2d: 3-27            [32, 256, 56, 56]         512
# │    │    └─ReLU: 3-28                   [32, 256, 56, 56]         --
# ├─Sequential: 1-6                        [32, 512, 28, 28]         --
# │    └─Bottleneck: 2-4                   [32, 512, 28, 28]         --
# │    │    └─Conv2d: 3-29                 [32, 128, 56, 56]         32,768
# │    │    └─BatchNorm2d: 3-30            [32, 128, 56, 56]         256
# │    │    └─ReLU: 3-31                   [32, 128, 56, 56]         --
# │    │    └─Conv2d: 3-32                 [32, 128, 28, 28]         147,456
# │    │    └─BatchNorm2d: 3-33            [32, 128, 28, 28]         256
# │    │    └─ReLU: 3-34                   [32, 128, 28, 28]         --
# │    │    └─Conv2d: 3-35                 [32, 512, 28, 28]         65,536
# │    │    └─BatchNorm2d: 3-36            [32, 512, 28, 28]         1,024
# │    │    └─Sequential: 3-37             [32, 512, 28, 28]         132,096
# │    │    └─ReLU: 3-38                   [32, 512, 28, 28]         --
# │    └─Bottleneck: 2-5                   [32, 512, 28, 28]         --
# │    │    └─Conv2d: 3-39                 [32, 128, 28, 28]         65,536
# │    │    └─BatchNorm2d: 3-40            [32, 128, 28, 28]         256
# │    │    └─ReLU: 3-41                   [32, 128, 28, 28]         --
# │    │    └─Conv2d: 3-42                 [32, 128, 28, 28]         147,456
# │    │    └─BatchNorm2d: 3-43            [32, 128, 28, 28]         256
# │    │    └─ReLU: 3-44                   [32, 128, 28, 28]         --
# │    │    └─Conv2d: 3-45                 [32, 512, 28, 28]         65,536
# │    │    └─BatchNorm2d: 3-46            [32, 512, 28, 28]         1,024
# │    │    └─ReLU: 3-47                   [32, 512, 28, 28]         --
# │    └─Bottleneck: 2-6                   [32, 512, 28, 28]         --
# │    │    └─Conv2d: 3-48                 [32, 128, 28, 28]         65,536
# │    │    └─BatchNorm2d: 3-49            [32, 128, 28, 28]         256
# │    │    └─ReLU: 3-50                   [32, 128, 28, 28]         --
# │    │    └─Conv2d: 3-51                 [32, 128, 28, 28]         147,456
# │    │    └─BatchNorm2d: 3-52            [32, 128, 28, 28]         256
# │    │    └─ReLU: 3-53                   [32, 128, 28, 28]         --
# │    │    └─Conv2d: 3-54                 [32, 512, 28, 28]         65,536
# │    │    └─BatchNorm2d: 3-55            [32, 512, 28, 28]         1,024
# │    │    └─ReLU: 3-56                   [32, 512, 28, 28]         --
# │    └─Bottleneck: 2-7                   [32, 512, 28, 28]         --
# │    │    └─Conv2d: 3-57                 [32, 128, 28, 28]         65,536
# │    │    └─BatchNorm2d: 3-58            [32, 128, 28, 28]         256
# │    │    └─ReLU: 3-59                   [32, 128, 28, 28]         --
# │    │    └─Conv2d: 3-60                 [32, 128, 28, 28]         147,456
# │    │    └─BatchNorm2d: 3-61            [32, 128, 28, 28]         256
# │    │    └─ReLU: 3-62                   [32, 128, 28, 28]         --
# │    │    └─Conv2d: 3-63                 [32, 512, 28, 28]         65,536
# │    │    └─BatchNorm2d: 3-64            [32, 512, 28, 28]         1,024
# │    │    └─ReLU: 3-65                   [32, 512, 28, 28]         --
# ├─Sequential: 1-7                        [32, 1024, 14, 14]        --
# │    └─Bottleneck: 2-8                   [32, 1024, 14, 14]        --
# │    │    └─Conv2d: 3-66                 [32, 256, 28, 28]         131,072
# │    │    └─BatchNorm2d: 3-67            [32, 256, 28, 28]         512
# │    │    └─ReLU: 3-68                   [32, 256, 28, 28]         --
# │    │    └─Conv2d: 3-69                 [32, 256, 14, 14]         589,824
# │    │    └─BatchNorm2d: 3-70            [32, 256, 14, 14]         512
# │    │    └─ReLU: 3-71                   [32, 256, 14, 14]         --
# │    │    └─Conv2d: 3-72                 [32, 1024, 14, 14]        262,144
# │    │    └─BatchNorm2d: 3-73            [32, 1024, 14, 14]        2,048
# │    │    └─Sequential: 3-74             [32, 1024, 14, 14]        526,336
# │    │    └─ReLU: 3-75                   [32, 1024, 14, 14]        --
# │    └─Bottleneck: 2-9                   [32, 1024, 14, 14]        --
# │    │    └─Conv2d: 3-76                 [32, 256, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-77            [32, 256, 14, 14]         512
# │    │    └─ReLU: 3-78                   [32, 256, 14, 14]         --
# │    │    └─Conv2d: 3-79                 [32, 256, 14, 14]         589,824
# │    │    └─BatchNorm2d: 3-80            [32, 256, 14, 14]         512
# │    │    └─ReLU: 3-81                   [32, 256, 14, 14]         --
# │    │    └─Conv2d: 3-82                 [32, 1024, 14, 14]        262,144
# │    │    └─BatchNorm2d: 3-83            [32, 1024, 14, 14]        2,048
# │    │    └─ReLU: 3-84                   [32, 1024, 14, 14]        --
# │    └─Bottleneck: 2-10                  [32, 1024, 14, 14]        --
# │    │    └─Conv2d: 3-85                 [32, 256, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-86            [32, 256, 14, 14]         512
# │    │    └─ReLU: 3-87                   [32, 256, 14, 14]         --
# │    │    └─Conv2d: 3-88                 [32, 256, 14, 14]         589,824
# │    │    └─BatchNorm2d: 3-89            [32, 256, 14, 14]         512
# │    │    └─ReLU: 3-90                   [32, 256, 14, 14]         --
# │    │    └─Conv2d: 3-91                 [32, 1024, 14, 14]        262,144
# │    │    └─BatchNorm2d: 3-92            [32, 1024, 14, 14]        2,048
# │    │    └─ReLU: 3-93                   [32, 1024, 14, 14]        --
# │    └─Bottleneck: 2-11                  [32, 1024, 14, 14]        --
# │    │    └─Conv2d: 3-94                 [32, 256, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-95            [32, 256, 14, 14]         512
# │    │    └─ReLU: 3-96                   [32, 256, 14, 14]         --
# │    │    └─Conv2d: 3-97                 [32, 256, 14, 14]         589,824
# │    │    └─BatchNorm2d: 3-98            [32, 256, 14, 14]         512
# │    │    └─ReLU: 3-99                   [32, 256, 14, 14]         --
# │    │    └─Conv2d: 3-100                [32, 1024, 14, 14]        262,144
# │    │    └─BatchNorm2d: 3-101           [32, 1024, 14, 14]        2,048
# │    │    └─ReLU: 3-102                  [32, 1024, 14, 14]        --
# │    └─Bottleneck: 2-12                  [32, 1024, 14, 14]        --
# │    │    └─Conv2d: 3-103                [32, 256, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-104           [32, 256, 14, 14]         512
# │    │    └─ReLU: 3-105                  [32, 256, 14, 14]         --
# │    │    └─Conv2d: 3-106                [32, 256, 14, 14]         589,824
# │    │    └─BatchNorm2d: 3-107           [32, 256, 14, 14]         512
# │    │    └─ReLU: 3-108                  [32, 256, 14, 14]         --
# │    │    └─Conv2d: 3-109                [32, 1024, 14, 14]        262,144
# │    │    └─BatchNorm2d: 3-110           [32, 1024, 14, 14]        2,048
# │    │    └─ReLU: 3-111                  [32, 1024, 14, 14]        --
# │    └─Bottleneck: 2-13                  [32, 1024, 14, 14]        --
# │    │    └─Conv2d: 3-112                [32, 256, 14, 14]         262,144
# │    │    └─BatchNorm2d: 3-113           [32, 256, 14, 14]         512
# │    │    └─ReLU: 3-114                  [32, 256, 14, 14]         --
# │    │    └─Conv2d: 3-115                [32, 256, 14, 14]         589,824
# │    │    └─BatchNorm2d: 3-116           [32, 256, 14, 14]         512
# │    │    └─ReLU: 3-117                  [32, 256, 14, 14]         --
# │    │    └─Conv2d: 3-118                [32, 1024, 14, 14]        262,144
# │    │    └─BatchNorm2d: 3-119           [32, 1024, 14, 14]        2,048
# │    │    └─ReLU: 3-120                  [32, 1024, 14, 14]        --
# ├─Sequential: 1-8                        [32, 2048, 7, 7]          --
# │    └─Bottleneck: 2-14                  [32, 2048, 7, 7]          --
# │    │    └─Conv2d: 3-121                [32, 512, 14, 14]         524,288
# │    │    └─BatchNorm2d: 3-122           [32, 512, 14, 14]         1,024
# │    │    └─ReLU: 3-123                  [32, 512, 14, 14]         --
# │    │    └─Conv2d: 3-124                [32, 512, 7, 7]           2,359,296
# │    │    └─BatchNorm2d: 3-125           [32, 512, 7, 7]           1,024
# │    │    └─ReLU: 3-126                  [32, 512, 7, 7]           --
# │    │    └─Conv2d: 3-127                [32, 2048, 7, 7]          1,048,576
# │    │    └─BatchNorm2d: 3-128           [32, 2048, 7, 7]          4,096
# │    │    └─Sequential: 3-129            [32, 2048, 7, 7]          2,101,248
# │    │    └─ReLU: 3-130                  [32, 2048, 7, 7]          --
# │    └─Bottleneck: 2-15                  [32, 2048, 7, 7]          --
# │    │    └─Conv2d: 3-131                [32, 512, 7, 7]           1,048,576
# │    │    └─BatchNorm2d: 3-132           [32, 512, 7, 7]           1,024
# │    │    └─ReLU: 3-133                  [32, 512, 7, 7]           --
# │    │    └─Conv2d: 3-134                [32, 512, 7, 7]           2,359,296
# │    │    └─BatchNorm2d: 3-135           [32, 512, 7, 7]           1,024
# │    │    └─ReLU: 3-136                  [32, 512, 7, 7]           --
# │    │    └─Conv2d: 3-137                [32, 2048, 7, 7]          1,048,576
# │    │    └─BatchNorm2d: 3-138           [32, 2048, 7, 7]          4,096
# │    │    └─ReLU: 3-139                  [32, 2048, 7, 7]          --
# │    └─Bottleneck: 2-16                  [32, 2048, 7, 7]          --
# │    │    └─Conv2d: 3-140                [32, 512, 7, 7]           1,048,576
# │    │    └─BatchNorm2d: 3-141           [32, 512, 7, 7]           1,024
# │    │    └─ReLU: 3-142                  [32, 512, 7, 7]           --
# │    │    └─Conv2d: 3-143                [32, 512, 7, 7]           2,359,296
# │    │    └─BatchNorm2d: 3-144           [32, 512, 7, 7]           1,024
# │    │    └─ReLU: 3-145                  [32, 512, 7, 7]           --
# │    │    └─Conv2d: 3-146                [32, 2048, 7, 7]          1,048,576
# │    │    └─BatchNorm2d: 3-147           [32, 2048, 7, 7]          4,096
# │    │    └─ReLU: 3-148                  [32, 2048, 7, 7]          --
# ├─AdaptiveAvgPool2d: 1-9                 [32, 2048, 1, 1]          --
# ├─Linear: 1-10                           [32, 1000]                2,049,000
# ==========================================================================================
# Total params: 25,557,032
# Trainable params: 25,557,032
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 130.86
# ==========================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 5690.62
# Params size (MB): 102.23
# Estimated Total Size (MB): 5812.11
# ==========================================================================================

# %% [markdown]
# Lets freeze the model weights.

# %%
for params in model.parameters():
    params.requires_grad = False

# %% [markdown]
# As this model is created using ImageNet dataset, which has 1000 classes of data, we need the change the model's last layer as per our need.

# %%
# Number of inputs for the final layers
in_features = model.fc.in_features

# %% [markdown]
# Now lets define our own classifier for the pretrained model

# %%
classifier = nn.Sequential(
    nn.Linear(in_features, 256),
    nn.ReLU(),
    nn.Dropout(p=0.5),

    nn.Linear(256, len(dataset.classes))
)

# %% [markdown]
# Lets replace the final layer of the pretrained model using our own classifier.

# %%
model.fc = classifier

# %% [markdown]
# lets check our model again.

# %%
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=256, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# We will use CrossEntropy as loss function and Adam as optimizer. The optimizer will only be applied on the custom layer that we made. Now on the whole model. Lets also apply weight decay to apply regularization to our model.

# %%
model.to(device)

optimizer = optim.Adam(model.fc.parameters(), weight_decay=1e-5)
loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# Now we will create a function whcih runs our model for one epoch. The function takes model, optimizer, loss function, data loader object and device as input  and returns the average training loss for that epoch.

# %%
def train_epoch(model, optimizer, loss_fn, data_loader, device="cpu"):
    # We'll report the loss function's average value at the end of the epoch.
    training_loss = 0.0

    # The train method simply sets the model in training mode. No training
    # has happened.
    model.train()

    # We iterate over all batches in the training set to complete one epoch
    for inputs, targets in tqdm(data_loader, desc="Training", leave=False):
        # Sets the gradients to zero. We need to do this every time.
        optimizer.zero_grad()

        # Unpack images (X) and labels (y) from the batch and add those
        # tensors to the specified device.
        inputs = inputs.to(device)
        targets = targets.to(device)

        # We make a forward pass through the network and obtain the logits.
        # With the logits, we can calculate our loss.
        output = model(inputs)
        loss = loss_fn(output, targets)

        # After calculating our loss, we calculate the numerical value of
        # the derivative of our loss function with respect to all the
        # trainable model weights. Once we have the gradients calculated,
        # we let the optimizer take a "step", in other words, update or
        # adjust the model weights.
        loss.backward()
        optimizer.step()

        # We increment the training loss for the current batch
        training_loss += loss.data.item() * inputs.size(0)

    # We calculate the training loss over the completed epoch
    return training_loss / len(data_loader.dataset)

# %% [markdown]
# Let's create another function which calculates the accuracy score for each epoch.

# %% [markdown]
# This function takes model, data loader object, loss function and device as input and returns average loss and accuracy for one epoch.

# %%
def score(model, data_loader, loss_fn, device="cpu"):
    total_loss = 0
    total_correct = 0

    model.eval()
    with torch.no_grad():
        for inputs, targets in tqdm(data_loader, desc="Scoring", leave=False):
            inputs = inputs.to(device)
            output = model(inputs)

            targets = targets.to(device)
            loss = loss_fn(output, targets)
            total_loss += loss.data.item() * inputs.size(0)

            correct = torch.eq(torch.argmax(output, dim=1), targets)
            total_correct += torch.sum(correct).item()

    n_observations = data_loader.batch_size * len(data_loader)
    average_loss = total_loss / n_observations
    accuracy = total_correct / n_observations
    return average_loss, accuracy

# %% [markdown]
# We will impliment Callback methods.
#
# -> **Learning Rate Scheduling**: Adjusts the learning rate over time, which can lead  to better model performance.
#
# -> **Early Stopping**: Halts training when the model's performance stops improving, which prevents overfitting. We'll stop if validation loss doesn't improve for at least 5 epochs.
#
# -> **Checkpointing**: Saves the model every time validation loss gets better than in the epoch prior. This allows us to recover the best model once training completes.
#
# In order to use these callbacks, we need to implement them and then update the train function.
#
# For the Learning Rate Scheduling, we'll use **StepLR** from torch.optim. The StepLR scheduler decays the learning rate by multiplicative factor **gamma** every **step_size** epochs.

# %% [markdown]
# Lets create the learning rate scheduler.

# %%
step_size = 4
gamma = 0.2

scheduler = optim.lr_scheduler.StepLR(
    optimizer,
    step_size=step_size,
    gamma=gamma,
)

# %% [markdown]
# Now lets create an Early Stopping function. The function counts for how many epochs the best validation score is not beaten by the current validation score. If the for 5 epochs the best validation score is not beaten, this function will give the signal to stop the training.

# %%
def early_stopping(validation_loss, best_val_loss, counter):
    """Function that implements Early Stopping"""

    stop = False

    if validation_loss < best_val_loss:
        counter = 0
    else:
        counter += 1

    # Check if counter is >= patience (5 epochs in our case)
    # Set stop variable accordingly
    if counter >= 5:
        stop = True

    return counter, stop

# %% [markdown]
# Lets create another function which will create checkpoints for our model. This function saves the model if validation loss improves in the current epoch. This function requires a path, where the checkpoints will be saved.

# %%
def checkpointing(validation_loss, best_val_loss, model, optimizer, save_path):

    if validation_loss < best_val_loss:
        torch.save(
            {
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "loss": best_val_loss,
            },
            save_path,
        )
        print(f"Checkpoint saved with validation loss {validation_loss:.4f}")

# %% [markdown]
# Now lets create our main Training function. The function takes model, optimizer, loss function, train data loader, validation data loader, number of epochs we want to train, device, learning rate scheduler, checkpointing path, and early stopping function. The function returns learning_rates, train_losses, val_losses, train_accuracies, val_accuracies, number epoch our model trained before early stopping kicked in.

# %%
def train(
    model,
    optimizer,
    loss_fn,
    train_loader,
    val_loader,
    epochs=20,
    device="cpu",
    scheduler=None,
    checkpoint_path=None,
    early_stopping=None,
):
    # Track the model progress over epochs
    train_losses = []
    train_accuracies = []
    val_losses = []
    val_accuracies = []
    learning_rates = []

    # Create the trackers if needed for checkpointing and early stopping
    best_val_loss = float("inf")
    early_stopping_counter = 0

    print("Model evaluation before start of training...")
    # Test on training set
    train_loss, train_accuracy = score(model, train_loader, loss_fn, device)
    print(f"Training loss before Training: {train_loss:.4f}")
    print(f"Training accuracy before Training: {train_accuracy*100:.4f}%")
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)

    # Test on validation set
    validation_loss, validation_accuracy = score(model, val_loader, loss_fn, device)
    print(f"Validation loss before Training: {validation_loss:.4f}")
    print(f"Validation accuracy before Training: {validation_accuracy*100:.4f}%")
    val_losses.append(validation_loss)
    val_accuracies.append(validation_accuracy)

    for epoch in range(1, epochs + 1):
        print("\n")
        print(f"Starting epoch {epoch}/{epochs}")

        # Train one epoch
        train_epoch(model, optimizer, loss_fn, train_loader, device)

        # Evaluate training results
        train_loss, train_accuracy = score(model, train_loader, loss_fn, device)
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)

        # Test on validation set
        validation_loss, validation_accuracy = score(model, val_loader, loss_fn, device)
        val_losses.append(validation_loss)
        val_accuracies.append(validation_accuracy)

        print(f"Epoch: {epoch}")
        print(f"Training loss: {train_loss:.4f}")
        print(f"Training accuracy: {train_accuracy*100:.4f}%")
        print(f"Validation loss: {validation_loss:.4f}")
        print(f"Validation accuracy: {validation_accuracy*100:.4f}%")

        # # Log the learning rate and have the scheduler adjust it
        lr = optimizer.param_groups[0]["lr"]
        learning_rates.append(lr)
        if scheduler:
            scheduler.step()

        # Checkpointing saves the model if current model is better than best so far
        if checkpoint_path:
            checkpointing(
                validation_loss, best_val_loss, model, optimizer, checkpoint_path
            )

        # Early Stopping
        if early_stopping:
            early_stopping_counter, stop = early_stopping(
                validation_loss, best_val_loss, early_stopping_counter
            )
            if stop:
                print(f"Early stopping triggered after {epoch} epochs")
                break

        if validation_loss < best_val_loss:
            best_val_loss = validation_loss

    return (
        learning_rates,
        train_losses,
        val_losses,
        train_accuracies,
        val_accuracies,
        epoch,
    )

# %% [markdown]
# Now lets train our ann model for 50 epochs and see the results. Also lets lets create a checkpointing path

# %%
epochs_to_train = 50
checkpoint_file_path = "LR_model.pth"

# %%
train_results = train(
    model,
    optimizer,
    loss_fn,
    train_loader,
    val_loader,
    epochs=epochs_to_train,
    device=device,
    scheduler=scheduler,
    checkpoint_path=checkpoint_file_path,
    early_stopping=early_stopping,
)

(
    learning_rates,
    train_losses,
    valid_losses,
    train_accuracies,
    valid_accuracies,
    epochs,
) = train_results
# Out:
# Model evaluation before start of training...
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Training loss before Training: 1.0879
# Training accuracy before Training: 33.7406%
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Validation loss before Training: 1.0862
# Validation accuracy before Training: 33.8816%
#
#
# Starting epoch 1/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 1
# Training loss: 0.1903
# Training accuracy: 92.9746%
# Validation loss: 0.2387
# Validation accuracy: 91.5296%
# Checkpoint saved with validation loss 0.2387
#
#
# Starting epoch 2/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 2
# Training loss: 0.1284
# Training accuracy: 95.4652%
# Validation loss: 0.2091
# Validation accuracy: 92.2697%
# Checkpoint saved with validation loss 0.2091
#
#
# Starting epoch 3/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 3
# Training loss: 0.0749
# Training accuracy: 97.6974%
# Validation loss: 0.1698
# Validation accuracy: 93.5855%
# Checkpoint saved with validation loss 0.1698
#
#
# Starting epoch 4/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 4
# Training loss: 0.0650
# Training accuracy: 97.7444%
# Validation loss: 0.1639
# Validation accuracy: 93.9145%
# Checkpoint saved with validation loss 0.1639
#
#
# Starting epoch 5/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 5
# Training loss: 0.0488
# Training accuracy: 98.4492%
# Validation loss: 0.1558
# Validation accuracy: 94.4079%
# Checkpoint saved with validation loss 0.1558
#
#
# Starting epoch 6/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 6
# Training loss: 0.0432
# Training accuracy: 98.5902%
# Validation loss: 0.1521
# Validation accuracy: 93.8322%
# Checkpoint saved with validation loss 0.1521
#
#
# Starting epoch 7/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 7
# Training loss: 0.0390
# Training accuracy: 98.6372%
# Validation loss: 0.1478
# Validation accuracy: 94.1612%
# Checkpoint saved with validation loss 0.1478
#
#
# Starting epoch 8/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 8
# Training loss: 0.0380
# Training accuracy: 98.8487%
# Validation loss: 0.1455
# Validation accuracy: 94.3257%
# Checkpoint saved with validation loss 0.1455
#
#
# Starting epoch 9/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 9
# Training loss: 0.0348
# Training accuracy: 98.8017%
# Validation loss: 0.1505
# Validation accuracy: 94.4901%
#
#
# Starting epoch 10/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 10
# Training loss: 0.0344
# Training accuracy: 98.8487%
# Validation loss: 0.1491
# Validation accuracy: 94.1612%
#
#
# Starting epoch 11/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 11
# Training loss: 0.0337
# Training accuracy: 98.8252%
# Validation loss: 0.1428
# Validation accuracy: 94.5724%
# Checkpoint saved with validation loss 0.1428
#
#
# Starting epoch 12/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 12
# Training loss: 0.0317
# Training accuracy: 98.9427%
# Validation loss: 0.1502
# Validation accuracy: 94.0789%
#
#
# Starting epoch 13/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 13
# Training loss: 0.0342
# Training accuracy: 98.8252%
# Validation loss: 0.1507
# Validation accuracy: 94.0789%
#
#
# Starting epoch 14/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 14
# Training loss: 0.0312
# Training accuracy: 98.8252%
# Validation loss: 0.1483
# Validation accuracy: 93.9145%
#
#
# Starting epoch 15/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 15
# Training loss: 0.0310
# Training accuracy: 98.9427%
# Validation loss: 0.1503
# Validation accuracy: 94.0789%
#
#
# Starting epoch 16/50
# Training:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/133 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 16
# Training loss: 0.0317
# Training accuracy: 98.8722%
# Validation loss: 0.1465
# Validation accuracy: 94.4901%
# Early stopping triggered after 16 epochs

# %% [markdown]
# Now lets evaluate our Models performance over the normal dataset.

# %% [markdown]
# Lets plot training and validation losses over the epochs.

# %%
plt.plot(train_losses, label="Training Loss")
plt.plot(valid_losses, label="Validation Loss")
plt.ylim([0, 1.7])
plt.title("Loss over epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend();

# %% [markdown]
# Also lets plot training and validation accuracy over the epochs.

# %%
plt.plot(train_accuracies, label="Training Accuracy")
plt.plot(valid_accuracies, label="Validation Accuracy")
plt.ylim([0, 1])
plt.title("Accuracy over epochs")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend();

# %% [markdown]
# As we can see our model has trained pretty well with very low overfitting. So we can say the model has generalised well.

# %% [markdown]
# Let's also inspect how the learning rate was changing during training due to the fact that we used a Learning Rate Scheduling Callback.

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs + 1), learning_rates, marker="o", label="Learning Rate")
plt.title("Learning Rate Schedule")
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.show()

# %% [markdown]
# As expected the learning rate has reduced for every 4 epochs.

# %% [markdown]
# Now it's time load the best model that we saved with checkpointing!

# %%
checkpoint = torch.load(checkpoint_file_path)
# Load the state dictionaries
model.load_state_dict(checkpoint["model_state_dict"])
optimizer.load_state_dict(checkpoint["optimizer_state_dict"])

# %% [markdown]
# We will use the best model to calculate predictions and evaluate on the testing set.

# %% [markdown]
# Lets create a predict function which returns the model's predicted probabilities for each class for each image. We can use this function to plot a confusion matrix for our test set and see the performance.

# %% [markdown]
# The function takes model, data loader object and device as inputs and returns a tensor of predictions.

# %%
def predict(model, data_loader, device="cpu"):
    # This tensor will store all of the predictions.
    all_probs = torch.tensor([]).to(device)

    # We set the model to evaluation mode. This mode is the opposite of
    # train mode we set in the train_epoch function.
    model.eval()

    # Since we're not training, we don't need any gradient calculations.
    # This tells PyTorch not to calculate any gradients, which speeds up
    # some calculations.
    with torch.no_grad():

        # Again, we iterate over the batches in the data loader and feed
        # them into the model for the forward pass.
        for inputs, targets in tqdm(data_loader, desc="Predicting", leave=False):
            inputs = inputs.to(device)
            output = model(inputs)

            # The model produces the logits.  This softmax function turns the
            # logits into probabilities.  These probabilities are concatenated
            # into the `all_probs` tensor.
            probs = F.softmax(output, dim=1)
            all_probs = torch.cat((all_probs, probs), dim=0)

    return all_probs

# %% [markdown]
# Here we are getting probabilities for each class for every image in our test dataset.

# %%
probabilities_test = predict(model, test_loader, device)
# Out:
# Predicting:   0%|          | 0/19 [00:00<?, ?it/s]

# %%
probabilities_test[0]
# Out:
# tensor([4.8091e-04, 9.9924e-01, 2.7902e-04], device='cuda:0')

# %% [markdown]
# The sum of the probability for all the classes for an image is 1. We can verify that here.

# %%
probabilities_test[0].sum()
# Out:
# tensor(1., device='cuda:0')

# %% [markdown]
# Now lets turn the predicted probabilities into prediction labels.

# %%
predictions_test = torch.argmax(probabilities_test, dim=1)
print(f"There are the first 10 predictions on our test set: {predictions_test[:10]}")
# Out:
# There are the first 10 predictions on our test set: tensor([1, 1, 2, 0, 0, 1, 0, 1, 1, 1], device='cuda:0')

# %% [markdown]
# Lets get the true labels of our test dataset.

# %%
true_test = torch.cat([labels for _, labels in test_loader]).to(device)
print(f"There are the first 10 true labels of our test set: {predictions_test[:10]}")
# Out:
# There are the first 10 true labels of our test set: tensor([1, 1, 2, 0, 0, 1, 0, 1, 1, 1], device='cuda:0')

# %% [markdown]
# Now Lets create a Confusion matrix using the true labels and the predicted labels of our model for test data.

# %%
cm = confusion_matrix(true_test.cpu(), predictions_test.cpu())
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['brain_glioma', 'brain_menin', 'brain_tumor'])

disp.plot(cmap=plt.cm.Blues, xticks_rotation="vertical");

# %% [markdown]
# Also Lets calcuate the accuracy for the test set

# %%
correct_predictions = np.trace(cm)
total_samples = np.sum(cm)

accuracy = (correct_predictions / total_samples) * 100
print(f"Accuracy calculated from Confusion Matrix: {accuracy:.2f}%")
# Out:
# Accuracy calculated from Confusion Matrix: 96.37%

# %% [markdown]
# The models accuracy on the test set is around 96% on the test set. But there is some Overfitting. Lets see if we can reduce this using augmented training.

# %% [markdown]
# Now lets train our model on the aumented dataset. Lets create our augmented train data. validation and test data will be normal as before

# %%
aug_train_set, val_set, test_set = subset_dataset(data_dir, 0.7, 0.2, 0.1, augmented_transforms=augmented_transformations)

# %% [markdown]
# Lets Check the class counts of the new subsets

# %%
class_counts(aug_train_set, class_to_idx_mapping)
# Out:
# brain_glioma    4206
# brain_menin     4209
# brain_tumor     4299
# dtype: int64

# %%
class_counts(val_set, class_to_idx_mapping)
# Out:
# Counting classes:   0%|          | 0/1212 [00:00<?, ?it/s]
# brain_glioma    401
# brain_menin     401
# brain_tumor     410
# dtype: int64

# %%
class_counts(test_set, class_to_idx_mapping)
# Out:
# Counting classes:   0%|          | 0/606 [00:00<?, ?it/s]
# brain_glioma    201
# brain_menin     200
# brain_tumor     205
# dtype: int64

# %% [markdown]
# As we can see our training set has lot more data now.

# %% [markdown]
# Now lets create the dataloaders

# %%
g = torch.Generator().manual_seed(42)

batch_size = 32

train_loader = DataLoader(aug_train_set, batch_size=batch_size, shuffle=True, generator=g, pin_memory=True)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False, generator=g, pin_memory=True)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False, generator=g, pin_memory=True)

# %% [markdown]
# We will use same loss function, optimizer and learning rate scheduler as before.

# %%
step_size = 4
gamma = 0.2

scheduler = optim.lr_scheduler.StepLR(
    optimizer,
    step_size=step_size,
    gamma=gamma,
)

# %% [markdown]
# We will use the same model but now on the augmented training data. We will train our new model for 100 epochs. Lets see if the model performance improves or not.

# %%
epochs_to_train = 100

# %%
train_results = train(
    model,
    optimizer,
    loss_fn,
    train_loader,
    val_loader,
    epochs=epochs_to_train,
    device=device,
    scheduler=scheduler,
    checkpoint_path=checkpoint_file_path,
    early_stopping=early_stopping,
)

(
    learning_rates,
    aug_train_losses,
    aug_valid_losses,
    aug_train_accuracies,
    aug_valid_accuracies,
    epochs,
) = train_results
# Out:
# Model evaluation before start of training...
# Scoring:   0%|          | 0/398 [00:00<?, ?it/s]
# Training loss before Training: 0.1223
# Training accuracy before Training: 95.4460%
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Validation loss before Training: 0.1428
# Validation accuracy before Training: 94.5724%
#
#
# Starting epoch 1/100
# Training:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 1
# Training loss: 0.1004
# Training accuracy: 96.3568%
# Validation loss: 0.1464
# Validation accuracy: 94.8191%
# Checkpoint saved with validation loss 0.1464
#
#
# Starting epoch 2/100
# Training:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 2
# Training loss: 0.0961
# Training accuracy: 96.7337%
# Validation loss: 0.1422
# Validation accuracy: 94.9013%
# Checkpoint saved with validation loss 0.1422
#
#
# Starting epoch 3/100
# Training:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 3
# Training loss: 0.1051
# Training accuracy: 96.3646%
# Validation loss: 0.1443
# Validation accuracy: 94.4901%
#
#
# Starting epoch 4/100
# Training:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 4
# Training loss: 0.0980
# Training accuracy: 96.4353%
# Validation loss: 0.1413
# Validation accuracy: 94.6546%
# Checkpoint saved with validation loss 0.1413
#
#
# Starting epoch 5/100
# Training:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 5
# Training loss: 0.0992
# Training accuracy: 96.5766%
# Validation loss: 0.1418
# Validation accuracy: 95.1480%
#
#
# Starting epoch 6/100
# Training:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 6
# Training loss: 0.0886
# Training accuracy: 96.9535%
# Validation loss: 0.1364
# Validation accuracy: 94.8191%
# Checkpoint saved with validation loss 0.1364
#
#
# Starting epoch 7/100
# Training:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 7
# Training loss: 0.0970
# Training accuracy: 96.6080%
# Validation loss: 0.1400
# Validation accuracy: 94.7368%
#
#
# Starting epoch 8/100
# Training:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 8
# Training loss: 0.0914
# Training accuracy: 96.8750%
# Validation loss: 0.1407
# Validation accuracy: 94.9836%
#
#
# Starting epoch 9/100
# Training:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 9
# Training loss: 0.0932
# Training accuracy: 96.7337%
# Validation loss: 0.1432
# Validation accuracy: 94.6546%
#
#
# Starting epoch 10/100
# Training:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 10
# Training loss: 0.0924
# Training accuracy: 96.7808%
# Validation loss: 0.1375
# Validation accuracy: 95.0658%
#
#
# Starting epoch 11/100
# Training:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/398 [00:00<?, ?it/s]
# Scoring:   0%|          | 0/38 [00:00<?, ?it/s]
# Epoch: 11
# Training loss: 0.0936
# Training accuracy: 96.7494%
# Validation loss: 0.1365
# Validation accuracy: 95.0658%
# Early stopping triggered after 11 epochs

# %% [markdown]
# Lets plot loss and accuracy curvs

# %%
plt.plot(train_losses + aug_train_losses, label="Training Loss")
plt.plot(valid_losses + aug_valid_losses, label="Validation Loss")
plt.ylim([0, 1.7])
plt.title("Loss over epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend();

# %%
plt.plot(train_accuracies + aug_train_accuracies, label="Training Accuracy")
plt.plot(valid_accuracies + aug_valid_accuracies, label="Validation Accuracy")
plt.ylim([0, 1])
plt.title("Accuracy over epochs")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend();

# %% [markdown]
# As we can see, though our model has not improved in terms of accuracy, but there is no overfitting like before. So we can say the model has generalised very well.

# %% [markdown]
# Lets also plot learning rate change

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs + 1), learning_rates, marker="o", label="Learning Rate")
plt.title("Learning Rate Schedule")
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.show()

# %% [markdown]
# now lets plot confusion matrix on the test set.

# %%
probabilities_test = predict(model, test_loader, device)
predictions_test = torch.argmax(probabilities_test, dim=1)
true_test = torch.cat([labels for _, labels in test_loader]).to(device)

cm = confusion_matrix(true_test.cpu(), predictions_test.cpu())
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['brain_glioma', 'brain_menin', 'brain_tumor'])

disp.plot(cmap=plt.cm.Blues, xticks_rotation="vertical");
# Out:
# Predicting:   0%|          | 0/19 [00:00<?, ?it/s]

# %% [markdown]
# Lets calculate the accuracy on the test set

# %%
correct_predictions = np.trace(cm)
total_samples = np.sum(cm)

accuracy = (correct_predictions / total_samples)*100
print(f"Accuracy calculated from Confusion Matrix: {accuracy:.2f}%")
# Out:
# Accuracy calculated from Confusion Matrix: 95.38%
